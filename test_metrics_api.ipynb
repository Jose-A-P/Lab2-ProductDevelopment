# %%
import pandas as pd
import numpy as np
import requests
import json

API_URL = "http://127.0.0.1:8000/metrics"

r = requests.post(API_URL, timeout=30)
r.raise_for_status()
resp = r.json()

print(resp)
# Out:
# {'model': 'RandomForestRegressor', 'accuracy': 0.798, 'predictions_served': 50, 'last_training': '2025-11-15', 'avg_response_time_seconds': 0.013704776763916016}
